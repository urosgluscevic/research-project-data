# %%
import pandas as pd

# %%
flow_commission_df = pd.read_csv('flow_commission.csv')
flow_df = pd.read_csv('flow.csv')
flow_milestone_df = pd.read_csv('flow_milestone.csv')

# %%
balance_to_balance_df = flow_df[(flow_df['from_asset'].str.contains("Balance")) & ((flow_df['to_asset'].str.contains('Balance')))]

# %%
balance_to_balance_df
# Out:
#      capacity      carrier  discount_rate  economic_lifetime       from_asset  \
# 440    1000.0  electricity            0.0                1.0     NL_E_Balance
# 441    1000.0  electricity            0.0                1.0     DE_E_Balance
# 442    1000.0  electricity            0.0                1.0     DE_E_Balance
# 443    1000.0  electricity            0.0                1.0     FR_E_Balance
# 444    1000.0  electricity            0.0                1.0     FR_E_Balance
# ..        ...          ...            ...                ...              ...
# 496    1000.0  electricity            0.0                1.0     RO_E_Balance
# 497    1000.0  electricity            0.0                1.0     RO_E_Balance
# 498    1000.0  electricity            0.0                1.0     CY_E_Balance
# 499    1000.0  electricity            0.0                1.0  OBZLL_E_Balance
# 500    1000.0  electricity            0.0                1.0  OBZLL_E_Balance
#
#      investment_integer  is_transport  technical_lifetime      to_asset
# 440               False          True                 1.0  BE_E_Balance
# 441               False          True                 1.0  NL_E_Balance
# 442               False          True                 1.0  BE_E_Balance
# 443               False          True                 1.0  DE_E_Balance
# 444               False          True                 1.0  BE_E_Balance
# ..                  ...           ...                 ...           ...
# 496               False          True                 1.0  BG_E_Balance
# 497               False          True                 1.0  HU_E_Balance
# 498               False          True                 1.0  GR_E_Balance
# 499               False          True                 1.0  NL_E_Balance
# 500               False          True                 1.0  UK_E_Balance
#
# [61 rows x 9 columns]

# %%
balance_to_balance_df['investable'] = 'true'
balance_to_balance_df['investment_cost'] = 2.6957550984694505
# Out:
# C:\Users\urosg\AppData\Local\Temp\ipykernel_11296\3839145157.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   balance_to_balance_df['investable'] = 'true'
# C:\Users\urosg\AppData\Local\Temp\ipykernel_11296\3839145157.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   balance_to_balance_df['investment_cost'] = 2.6957550984694505

# %%
merged = flow_commission_df.merge(balance_to_balance_df[['from_asset', 'to_asset', 'investment_cost']], on=['from_asset', 'to_asset'], how='left', suffixes=('', '_y'))


# merged
merged['investment_cost'] = merged['investment_cost_y']

merged = merged.drop(columns=['investment_cost_y'])

# merged['investable'] = merged['investable_y']

# merged = merged.drop(columns=['investable_y'])

merged['investment_cost'] = merged['investment_cost'].fillna(0.0)
# merged['investable'] = merged['investable'].fillna('false')
# Out:
#      commission_year  efficiency  fixed_cost  \
# 0               2050         1.0         0.0
# 1               2050         1.0         0.0
# 2               2050         1.0         0.0
# 3               2050         1.0         0.0
# 4               2050         1.0         0.0
# ..               ...         ...         ...
# 496             2050         1.0         0.0
# 497             2050         1.0         0.0
# 498             2050         1.0         0.0
# 499             2050         1.0         0.0
# 500             2050         1.0         0.0
#
#      flow_coefficient_in_capacity_constraint        from_asset  \
# 0                                        1.0      NL_E_Balance
# 1                                        1.0          NL_E_ENS
# 2                                        1.0   NL_Wind_Onshore
# 3                                        1.0  NL_Wind_Offshore
# 4                                        1.0          NL_Solar
# ..                                       ...               ...
# 496                                      1.0      RO_E_Balance
# 497                                      1.0      RO_E_Balance
# 498                                      1.0      CY_E_Balance
# 499                                      1.0   OBZLL_E_Balance
# 500                                      1.0   OBZLL_E_Balance
#
#      investment_cost  investment_limit      to_asset investable  \
# 0                0.0               NaN   NL_E_Demand        NaN
# 1                0.0               NaN   NL_E_Demand        NaN
# 2                0.0               NaN  NL_E_Balance        NaN
# 3                0.0               NaN  NL_E_Balance        NaN
# 4                0.0               NaN  NL_E_Balance        NaN
# ..               ...               ...           ...        ...
# 496              0.0               NaN  BG_E_Balance       true
# 497              0.0               NaN  HU_E_Balance       true
# 498              0.0               NaN  GR_E_Balance       true
# 499              0.0               NaN  NL_E_Balance       true
# 500              0.0               NaN  UK_E_Balance       true
#
#      investment_cost_y
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 496           2.695755
# 497           2.695755
# 498           2.695755
# 499           2.695755
# 500           2.695755
#
# [501 rows x 10 columns]

# %%
merged.to_csv('flow-commission-fixed-balances.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 merged_final.to_csv('flow-commission-fixed-balances.csv', index=False)
#
# NameError: name 'merged_final' is not defined

# %%
merged = flow_milestone_df.merge(balance_to_balance_df[['from_asset', 'to_asset', 'investable']], on=['from_asset', 'to_asset'], how='left', suffixes=('', '_y'))


# merged
# merged['investment_cost'] = merged['investment_cost_y']

# merged = merged.drop(columns=['investment_cost_y'])

merged['investable'] = merged['investable_y']

merged = merged.drop(columns=['investable_y'])

# merged['investment_cost'] = merged['investment_cost'].fillna(0.0)
merged['investable'] = merged['investable'].fillna('false')

# %%
merged.to_csv('flow-milestone-fixed-balances.csv', index=False)
