# %%
import pandas as pd
import numpy as np

# %%
assets_rep_periods_partitions_df = pd.read_csv('assets_rep_periods_partitions.csv')

# %%
assets_rep_periods_partitions_df
# Out:
#                   asset  partition  rep_period specification  year
# 0              NL_Solar          1           1       uniform  2050
# 1       NL_Wind_Onshore          1           1       uniform  2050
# 2      NL_Wind_Offshore          1           1       uniform  2050
# 3               NL_Coal          1           1       uniform  2050
# 4            NL_Nuclear          1           1       uniform  2050
# ...                 ...        ...         ...           ...   ...
# 5595         X0_Balance          1          10       uniform  2050
# 5596   X0_Wind_Onshore2          1          10       uniform  2050
# 5597  X0_Wind_Offshore2          1          10       uniform  2050
# 5598           X0_Coal2          1          10       uniform  2050
# 5599        X0_Nuclear2          1          10       uniform  2050
#
# [5600 rows x 5 columns]

# %%
flows_rep_periods_partitions = pd.read_csv('flows_rep_periods_partitions.csv')

# %%
flows_rep_periods_partitions
# Out:
#             from_asset     to_asset  year  rep_period specification  partition
# 0           NL_Balance  NL_E_Demand  2050           1       uniform          1
# 1             NL_Solar   NL_Balance  2050           1       uniform          1
# 2      NL_Wind_Onshore   NL_Balance  2050           1       uniform          1
# 3     NL_Wind_Offshore   NL_Balance  2050           1       uniform          1
# 4              NL_Coal   NL_Balance  2050           1       uniform          1
# ...                ...          ...   ...         ...           ...        ...
# 6745        X9_Balance   UK_Balance  2050          10       uniform          1
# 6746        X9_Balance   FR_Balance  2050          10       uniform          1
# 6747        X0_Balance   BE_Balance  2050          10       uniform          1
# 6748        X0_Balance   DE_Balance  2050          10       uniform          1
# 6749        X0_Balance   FR_Balance  2050          10       uniform          1
#
# [6750 rows x 6 columns]

# %%
countries_resolutions = [('NL', 1), 
                         ('BE', 1), ('DE', 1), ('UK', 1), ('DK', 1), ('NO', 1), ('X1', 1), ('X2', 1), 
                         ('FR', 2), ('CH', 2), ('AT', 2), ('IE', 2), ('LU', 2), ('CZ', 2), ('PL', 2), ('SE', 2), ('X3', 2), ('X4', 2), 
                         ('ES', 3), ('IT', 3), ('SI', 3), ('HU', 3), ('SK', 3), ('FI', 3), ('LT', 3), ('X5', 3), ('X6', 3), 
                         ('PT', 4), ('HR', 4), ('RO', 4), ('GR', 4), ('LV', 4), ('EE', 4), ('CY', 4), ('MT', 4), ('X7', 4), ('X8', 4), 
                         ('BG', 5), ('X9', 5), ('X0', 5), ]

# %%
partition_map = {
    'NL': 1, 
    'BE': 1, 'DE': 1, 'UK': 1, 'DK': 1, 'NO': 1,
    'FR': 2, 'CH': 2, 'AT': 2, 'IE': 2, 'LU': 2, 'CZ': 2, 'PL': 2, 'SE': 2,
    'ES': 3, 'IT': 3, 'SI': 3, 'HU': 3, 'SK': 3, 'FI': 3, 'LT': 3,
    'PT': 4, 'HR': 4, 'RO': 4, 'GR': 4, 'LV': 4, 'EE': 4, 'CY': 4, 'MT': 4,
    'BG': 5, 'X1': 1, 'X2': 1, 'X3': 2, 'X4': 2, 'X5': 3, 'X6': 3, 'X7': 4, 'X8': 4, 'X9': 5, 'X0': 5
}

# %%
country_dfs = []

for (country_code, country_resolution) in countries_resolutions:
    country_df = assets_rep_periods_partitions_df[assets_rep_periods_partitions_df['asset'].str.contains(country_code)].copy()
    country_df['partition'] = country_resolution
    
    country_dfs.append(country_df)

# %%
concated_country_dfs = pd.concat(country_dfs)

# %%
concated_country_dfs
# Out:
#                   asset  partition  rep_period specification  year
# 0              NL_Solar          1           1       uniform  2050
# 1       NL_Wind_Onshore          1           1       uniform  2050
# 2      NL_Wind_Offshore          1           1       uniform  2050
# 3               NL_Coal          1           1       uniform  2050
# 4            NL_Nuclear          1           1       uniform  2050
# ...                 ...        ...         ...           ...   ...
# 5595         X0_Balance          5          10       uniform  2050
# 5596   X0_Wind_Onshore2          5          10       uniform  2050
# 5597  X0_Wind_Offshore2          5          10       uniform  2050
# 5598           X0_Coal2          5          10       uniform  2050
# 5599        X0_Nuclear2          5          10       uniform  2050
#
# [5600 rows x 5 columns]

# %%
country_dfs[0]
# Out:
#                  asset  partition  rep_period specification  year
# 0             NL_Solar          1           1       uniform  2050
# 1      NL_Wind_Onshore          1           1       uniform  2050
# 2     NL_Wind_Offshore          1           1       uniform  2050
# 3              NL_Coal          1           1       uniform  2050
# 4           NL_Nuclear          1           1       uniform  2050
# ..                 ...        ...         ...           ...   ...
# 135         NL_Balance          1          10       uniform  2050
# 136   NL_Wind_Onshore2          1          10       uniform  2050
# 137  NL_Wind_Offshore2          1          10       uniform  2050
# 138           NL_Coal2          1          10       uniform  2050
# 139        NL_Nuclear2          1          10       uniform  2050
#
# [140 rows x 5 columns]

# %%
merged = assets_rep_periods_partitions_df.merge(concated_country_dfs[['asset', 'partition', 'rep_period']], on=['asset', 'rep_period'], how='left', suffixes=('', '_y'))

merged['partition'] = merged['partition_y']

merged = merged.drop(columns=['partition_y'])

# %%
merged
# Out:
#                   asset  partition  rep_period specification  year
# 0              NL_Solar          1           1       uniform  2050
# 1       NL_Wind_Onshore          1           1       uniform  2050
# 2      NL_Wind_Offshore          1           1       uniform  2050
# 3               NL_Coal          1           1       uniform  2050
# 4            NL_Nuclear          1           1       uniform  2050
# ...                 ...        ...         ...           ...   ...
# 5595         X0_Balance          5          10       uniform  2050
# 5596   X0_Wind_Onshore2          5          10       uniform  2050
# 5597  X0_Wind_Offshore2          5          10       uniform  2050
# 5598           X0_Coal2          5          10       uniform  2050
# 5599        X0_Nuclear2          5          10       uniform  2050
#
# [5600 rows x 5 columns]

# %%
merged['partition'].unique()
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
merged[merged['partition'].isnull()]
# Out:
# Empty DataFrame
# Columns: [asset, partition, rep_period, specification, year]
# Index: []

# %%
merged.to_csv('assets_rep_periods_partitions-fix.csv', index=False)

# %%
merged
# Out:
#                   asset  partition  rep_period specification  year
# 0              NL_Solar          1           1       uniform  2050
# 1       NL_Wind_Onshore          1           1       uniform  2050
# 2      NL_Wind_Offshore          1           1       uniform  2050
# 3               NL_Coal          1           1       uniform  2050
# 4            NL_Nuclear          1           1       uniform  2050
# ...                 ...        ...         ...           ...   ...
# 5595         X0_Balance          5          10       uniform  2050
# 5596   X0_Wind_Onshore2          5          10       uniform  2050
# 5597  X0_Wind_Offshore2          5          10       uniform  2050
# 5598           X0_Coal2          5          10       uniform  2050
# 5599        X0_Nuclear2          5          10       uniform  2050
#
# [5600 rows x 5 columns]

# %%
flows_rep_periods_partitions
# Out:
#             from_asset     to_asset  year  rep_period specification  partition
# 0           NL_Balance  NL_E_Demand  2050           1       uniform          1
# 1             NL_Solar   NL_Balance  2050           1       uniform          1
# 2      NL_Wind_Onshore   NL_Balance  2050           1       uniform          1
# 3     NL_Wind_Offshore   NL_Balance  2050           1       uniform          1
# 4              NL_Coal   NL_Balance  2050           1       uniform          1
# ...                ...          ...   ...         ...           ...        ...
# 6745        X9_Balance   UK_Balance  2050          10       uniform          1
# 6746        X9_Balance   FR_Balance  2050          10       uniform          1
# 6747        X0_Balance   BE_Balance  2050          10       uniform          1
# 6748        X0_Balance   DE_Balance  2050          10       uniform          1
# 6749        X0_Balance   FR_Balance  2050          10       uniform          1
#
# [6750 rows x 6 columns]

# %%
def helper():
    from_code = flows_rep_periods_partitions['from_asset'].str.split('_').str[0]
    to_code = flows_rep_periods_partitions['to_asset'].str.split('_').str[0]
    
    from_val = from_code.map(partition_map)
    to_val = to_code.map(partition_map)
    
    unknown_from = from_code[~from_code.isin(partition_map)]
    unknown_to = to_code[~to_code.isin(partition_map)]

    print("Unknown 'from' codes:", unknown_from.unique())
    print("Unknown 'to' codes:", unknown_to.unique())
    
    return np.minimum(from_val, to_val)

# %%
flows_rep_periods_partitions['partition'] = helper()

flows_rep_periods_partitions['partition'] = flows_rep_periods_partitions['partition'].astype(int)
# Out:
# Unknown 'from' codes: ['X0']
# Unknown 'to' codes: ['X0']
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[21], line 3
#       1 flows_rep_periods_partitions['partition'] = helper()
# ----> 3 flows_rep_periods_partitions['partition'] = flows_rep_periods_partitions['partition'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:140, in astype_nansafe(arr, dtype, copy, skipna)
#     137     raise TypeError(f"cannot astype a timedelta from [{arr.dtype}] to [{dtype}]")
#     139 elif np.issubdtype(arr.dtype, np.floating) and is_integer_dtype(dtype):
# --> 140     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     142 elif is_object_dtype(arr.dtype):
#     143
#     144     # if we have a datetime/timedelta array of objects
#     145     # then coerce to a proper dtype and recall astype_nansafe
#     147     if is_datetime64_dtype(dtype):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:182, in _astype_float_to_int_nansafe(values, dtype, copy)
#     178 """
#     179 astype with a check preventing converting NaN to an meaningless integer value.
#     180 """
#     181 if not np.isfinite(values).all():
# --> 182     raise IntCastingNaNError(
#     183         "Cannot convert non-finite values (NA or inf) to integer"
#     184     )
#     185 if dtype.kind == "u":
#     186     # GH#45151
#     187     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
flows_rep_periods_partitions

# %%
flows_rep_periods_partitions.to_csv('flows_rep_periods_partitions-fix.csv', index=False)
