# %%
import pandas as pd

# %%
df = pd.read_excel('paper_data.xlsx', sheet_name='flow-milestone') # GABRIEL AND KAROL EXCEL (FROM MORALES' PAPER)

# %%
df_comm = pd.read_excel('paper_data.xlsx', sheet_name='flow-commission') # GABRIEL AND KAROL EXCEL (FROM MORALES' PAPER)

# %%
flow_commission_df = pd.read_csv('flow-commission.csv')
flow_df = pd.read_csv('flow.csv')
flow_milestone_df = pd.read_csv('flow-milestone.csv')

# %%
df
# Out:
#           from_asset      to_asset  milestone_year  investable  variable_cost  \
# 0       NL_E_Balance   BE_E_Demand            2050       False          14.00
# 1       BE_E_Balance   NL_E_Demand            2050       False          14.00
# 2       NL_E_Balance   NL_E_Demand            2050        True           0.00
# 3           NL_E_ENS   NL_E_Demand            2050        True        1000.00
# 4    NL_Wind_Onshore  NL_E_Balance            2050        True           2.06
# ..               ...           ...             ...         ...            ...
# 616       CY_Battery      CY_PEMEC            2050        True           0.00
# 617     CY_E_Balance      CY_PEMEC            2050        True           0.00
# 618         CY_PEMEC     CY_H2Tank            2050        True           0.00
# 619         CY_PEMFC   CY_E_Demand            2050        True           0.00
# 620        CY_H2Tank      CY_PEMFC            2050        True           0.00
#
#      reactance  dc_opf
# 0          0.3   False
# 1          0.3   False
# 2          0.3   False
# 3          0.3   False
# 4          0.3   False
# ..         ...     ...
# 616        0.3   False
# 617        0.3   False
# 618        0.3   False
# 619        0.3   False
# 620        0.3   False
#
# [621 rows x 7 columns]

# %%
flow_commission_df
# Out:
#      commission_year  efficiency  fixed_cost  \
# 0               2050         1.0         0.0
# 1               2050         1.0         0.0
# 2               2050         1.0         0.0
# 3               2050         1.0         0.0
# 4               2050         1.0         0.0
# ..               ...         ...         ...
# 590             2050         1.0         0.0
# 591             2050         1.0         0.0
# 592             2050         1.0         0.0
# 593             2050         1.0         0.0
# 594             2050         1.0         0.0
#
#      flow_coefficient_in_capacity_constraint        from_asset  \
# 0                                        1.0      NL_E_Balance
# 1                                        1.0          NL_E_ENS
# 2                                        1.0   NL_Wind_Onshore
# 3                                        1.0  NL_Wind_Offshore
# 4                                        1.0          NL_Solar
# ..                                       ...               ...
# 590                                      1.0      RO_E_Balance
# 591                                      1.0      RO_E_Balance
# 592                                      1.0      CY_E_Balance
# 593                                      1.0   OBZLL_E_Balance
# 594                                      1.0   OBZLL_E_Balance
#
#      investment_cost  investment_limit      to_asset
# 0                0.0               NaN   NL_E_Demand
# 1                0.0               NaN   NL_E_Demand
# 2                0.0               NaN  NL_E_Balance
# 3                0.0               NaN  NL_E_Balance
# 4                0.0               NaN  NL_E_Balance
# ..               ...               ...           ...
# 590              0.0               NaN  BG_E_Balance
# 591              0.0               NaN  HU_E_Balance
# 592              0.0               NaN  GR_E_Balance
# 593              0.0               NaN  NL_E_Balance
# 594              0.0               NaN  UK_E_Balance
#
# [595 rows x 8 columns]

# %%
flow_df
# Out:
#      capacity      carrier  discount_rate  economic_lifetime  \
# 0         0.0  electricity            0.0                1.0
# 1         0.0  electricity            0.0                1.0
# 2         0.0  electricity            0.0                1.0
# 3         0.0  electricity            0.0                1.0
# 4         0.0  electricity            0.0                1.0
# ..        ...          ...            ...                ...
# 590    1000.0  electricity            0.0                1.0
# 591    1000.0  electricity            0.0                1.0
# 592    1000.0  electricity            0.0                1.0
# 593    1000.0  electricity            0.0                1.0
# 594    1000.0  electricity            0.0                1.0
#
#            from_asset  investment_integer  is_transport  technical_lifetime  \
# 0        NL_E_Balance               False         False                 1.0
# 1            NL_E_ENS               False         False                 1.0
# 2     NL_Wind_Onshore               False         False                 1.0
# 3    NL_Wind_Offshore               False         False                 1.0
# 4            NL_Solar               False         False                 1.0
# ..                ...                 ...           ...                 ...
# 590      RO_E_Balance               False          True                 1.0
# 591      RO_E_Balance               False          True                 1.0
# 592      CY_E_Balance               False          True                 1.0
# 593   OBZLL_E_Balance               False          True                 1.0
# 594   OBZLL_E_Balance               False          True                 1.0
#
#          to_asset
# 0     NL_E_Demand
# 1     NL_E_Demand
# 2    NL_E_Balance
# 3    NL_E_Balance
# 4    NL_E_Balance
# ..            ...
# 590  BG_E_Balance
# 591  HU_E_Balance
# 592  GR_E_Balance
# 593  NL_E_Balance
# 594  UK_E_Balance
#
# [595 rows x 9 columns]

# %%
flow_milestone_df
# Out:
#            from_asset  investable  milestone_year      to_asset  \
# 0        NL_E_Balance       False            2050   NL_E_Demand
# 1            NL_E_ENS       False            2050   NL_E_Demand
# 2     NL_Wind_Onshore       False            2050  NL_E_Balance
# 3    NL_Wind_Offshore       False            2050  NL_E_Balance
# 4            NL_Solar       False            2050  NL_E_Balance
# ..                ...         ...             ...           ...
# 590      RO_E_Balance       False            2050  BG_E_Balance
# 591      RO_E_Balance       False            2050  HU_E_Balance
# 592      CY_E_Balance       False            2050  GR_E_Balance
# 593   OBZLL_E_Balance       False            2050  NL_E_Balance
# 594   OBZLL_E_Balance       False            2050  UK_E_Balance
#
#      variable_cost  reactance  dc_opf
# 0              0.0        0.3   False
# 1              1.0        0.3   False
# 2              0.0        0.3   False
# 3              0.0        0.3   False
# 4              0.0        0.3   False
# ..             ...        ...     ...
# 590            0.0        0.3   False
# 591            0.0        0.3   False
# 592            0.0        0.3   False
# 593            0.0        0.3   False
# 594            0.0        0.3   False
#
# [595 rows x 7 columns]

# %%
investable_rows = df[df["investable"]]

# %%
investable_rows
# Out:
#            from_asset      to_asset  milestone_year  investable  \
# 2        NL_E_Balance   NL_E_Demand            2050        True
# 3            NL_E_ENS   NL_E_Demand            2050        True
# 4     NL_Wind_Onshore  NL_E_Balance            2050        True
# 5    NL_Wind_Offshore  NL_E_Balance            2050        True
# 6            NL_Solar  NL_E_Balance            2050        True
# ..                ...           ...             ...         ...
# 616        CY_Battery      CY_PEMEC            2050        True
# 617      CY_E_Balance      CY_PEMEC            2050        True
# 618          CY_PEMEC     CY_H2Tank            2050        True
# 619          CY_PEMFC   CY_E_Demand            2050        True
# 620         CY_H2Tank      CY_PEMFC            2050        True
#
#      variable_cost  reactance  dc_opf
# 2             0.00        0.3   False
# 3          1000.00        0.3   False
# 4             2.06        0.3   False
# 5             4.17        0.3   False
# 6             0.00        0.3   False
# ..             ...        ...     ...
# 616           0.00        0.3   False
# 617           0.00        0.3   False
# 618           0.00        0.3   False
# 619           0.00        0.3   False
# 620           0.00        0.3   False
#
# [503 rows x 7 columns]

# %%
temp = investable_rows.merge(df_comm, on=['to_asset', 'from_asset'], how="left")

# %%
investable_flows = temp[["from_asset", "to_asset", "investment_cost", "investable"]]

# %%
# investable_flows = investable_rows[["from_asset", "to_asset", "investment_cost"]]

# %%
investable_flows['investable'] = 'true'
# Out:
# C:\Users\urosg\AppData\Local\Temp\ipykernel_25756\3138971277.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   investable_flows['investable'] = 'true'

# %%
investable_flows
# Out:
#            from_asset      to_asset  investment_cost investable
# 0        NL_E_Balance   NL_E_Demand              0.0       true
# 1            NL_E_ENS   NL_E_Demand              0.0       true
# 2     NL_Wind_Onshore  NL_E_Balance              0.0       true
# 3    NL_Wind_Offshore  NL_E_Balance              0.0       true
# 4            NL_Solar  NL_E_Balance              0.0       true
# ..                ...           ...              ...        ...
# 498        CY_Battery      CY_PEMEC              0.0       true
# 499      CY_E_Balance      CY_PEMEC              0.0       true
# 500          CY_PEMEC     CY_H2Tank              0.0       true
# 501          CY_PEMFC   CY_E_Demand              0.0       true
# 502         CY_H2Tank      CY_PEMFC              0.0       true
#
# [503 rows x 4 columns]

# %%
merged = flow_commission_df.merge(investable_flows[['from_asset', 'to_asset',  'investment_cost']], on=['from_asset', 'to_asset'], how='inner', suffixes=('', '_y'))

merged['investment_cost'] = merged['investment_cost_y']

merged = merged.drop(columns=['investment_cost_y'])

merged['investment_cost'] = merged['investment_cost'].fillna(0.0)

# %%
merged
# Out:
#      commission_year  efficiency  fixed_cost  \
# 0               2050       1.000         0.0
# 1               2050       1.000         0.0
# 2               2050       1.000         0.0
# 3               2050       1.000         0.0
# 4               2050       1.000         0.0
# ..               ...         ...         ...
# 262             2050       1.000         0.0
# 263             2050       1.000         0.0
# 264             2050       1.000         0.0
# 265             2050       1.000         0.0
# 266             2050       0.955         0.0
#
#      flow_coefficient_in_capacity_constraint        from_asset  \
# 0                                        1.0      NL_E_Balance
# 1                                        1.0          NL_E_ENS
# 2                                        1.0   NL_Wind_Onshore
# 3                                        1.0  NL_Wind_Offshore
# 4                                        1.0          NL_Solar
# ..                                       ...               ...
# 262                                      1.0      CY_E_Balance
# 263                                      1.0          CY_E_ENS
# 264                                      1.0   CY_Wind_Onshore
# 265                                      1.0          CY_Solar
# 266                                      1.0      CY_E_Balance
#
#      investment_cost  investment_limit      to_asset
# 0                0.0               NaN   NL_E_Demand
# 1                0.0               NaN   NL_E_Demand
# 2                0.0               NaN  NL_E_Balance
# 3                0.0               NaN  NL_E_Balance
# 4                0.0               NaN  NL_E_Balance
# ..               ...               ...           ...
# 262              0.0               NaN   CY_E_Demand
# 263              0.0               NaN   CY_E_Demand
# 264              0.0               NaN  CY_E_Balance
# 265              0.0               NaN  CY_E_Balance
# 266              0.0               NaN    CY_Battery
#
# [267 rows x 8 columns]

# %%
merged['investment_cost'] = 2.6957550984694505

# %%
merged_final = flow_commission_df.merge(merged[['from_asset', 'to_asset',  'investment_cost']], on=['from_asset', 'to_asset'], how='left', suffixes=('', '_y'))

merged_final['investment_cost'] = merged_final['investment_cost_y']

merged_final = merged_final.drop(columns=['investment_cost_y'])

merged_final['investment_cost'] = merged_final['investment_cost'].fillna(0.0)

# %%
merged_final
# Out:
#      commission_year  efficiency  fixed_cost  \
# 0               2050         1.0         0.0
# 1               2050         1.0         0.0
# 2               2050         1.0         0.0
# 3               2050         1.0         0.0
# 4               2050         1.0         0.0
# ..               ...         ...         ...
# 590             2050         1.0         0.0
# 591             2050         1.0         0.0
# 592             2050         1.0         0.0
# 593             2050         1.0         0.0
# 594             2050         1.0         0.0
#
#      flow_coefficient_in_capacity_constraint        from_asset  \
# 0                                        1.0      NL_E_Balance
# 1                                        1.0          NL_E_ENS
# 2                                        1.0   NL_Wind_Onshore
# 3                                        1.0  NL_Wind_Offshore
# 4                                        1.0          NL_Solar
# ..                                       ...               ...
# 590                                      1.0      RO_E_Balance
# 591                                      1.0      RO_E_Balance
# 592                                      1.0      CY_E_Balance
# 593                                      1.0   OBZLL_E_Balance
# 594                                      1.0   OBZLL_E_Balance
#
#      investment_cost  investment_limit      to_asset
# 0           2.695755               NaN   NL_E_Demand
# 1           2.695755               NaN   NL_E_Demand
# 2           2.695755               NaN  NL_E_Balance
# 3           2.695755               NaN  NL_E_Balance
# 4           2.695755               NaN  NL_E_Balance
# ..               ...               ...           ...
# 590         0.000000               NaN  BG_E_Balance
# 591         0.000000               NaN  HU_E_Balance
# 592         0.000000               NaN  GR_E_Balance
# 593         0.000000               NaN  NL_E_Balance
# 594         0.000000               NaN  UK_E_Balance
#
# [595 rows x 8 columns]

# %%
# merged_final.to_csv('flow-commission-fixed.csv', index=False)

# %%
merged = flow_milestone_df.merge(investable_flows[['from_asset', 'to_asset', 'investable']], on=['from_asset', 'to_asset'], how='left', suffixes=('', '_y'))

merged['investable'] = merged['investable_y']

merged = merged.drop(columns=['investable_y'])

merged['investable'] = merged['investable'].fillna('false')

# %%
investable_flows
# Out:
#            from_asset      to_asset  investment_cost investable
# 0        NL_E_Balance   NL_E_Demand              0.0       true
# 1            NL_E_ENS   NL_E_Demand              0.0       true
# 2     NL_Wind_Onshore  NL_E_Balance              0.0       true
# 3    NL_Wind_Offshore  NL_E_Balance              0.0       true
# 4            NL_Solar  NL_E_Balance              0.0       true
# ..                ...           ...              ...        ...
# 498        CY_Battery      CY_PEMEC              0.0       true
# 499      CY_E_Balance      CY_PEMEC              0.0       true
# 500          CY_PEMEC     CY_H2Tank              0.0       true
# 501          CY_PEMFC   CY_E_Demand              0.0       true
# 502         CY_H2Tank      CY_PEMFC              0.0       true
#
# [503 rows x 4 columns]

# %%
merged
# Out:
#            from_asset investable  milestone_year      to_asset  variable_cost  \
# 0        NL_E_Balance       true            2050   NL_E_Demand            0.0
# 1            NL_E_ENS       true            2050   NL_E_Demand            1.0
# 2     NL_Wind_Onshore       true            2050  NL_E_Balance            0.0
# 3    NL_Wind_Offshore       true            2050  NL_E_Balance            0.0
# 4            NL_Solar       true            2050  NL_E_Balance            0.0
# ..                ...        ...             ...           ...            ...
# 590      RO_E_Balance      false            2050  BG_E_Balance            0.0
# 591      RO_E_Balance      false            2050  HU_E_Balance            0.0
# 592      CY_E_Balance      false            2050  GR_E_Balance            0.0
# 593   OBZLL_E_Balance      false            2050  NL_E_Balance            0.0
# 594   OBZLL_E_Balance      false            2050  UK_E_Balance            0.0
#
#      reactance  dc_opf
# 0          0.3   False
# 1          0.3   False
# 2          0.3   False
# 3          0.3   False
# 4          0.3   False
# ..         ...     ...
# 590        0.3   False
# 591        0.3   False
# 592        0.3   False
# 593        0.3   False
# 594        0.3   False
#
# [595 rows x 7 columns]

# %%
# merged.to_csv('flow-milestone-fixed.csv', index=False)

# %%
investable_flows['investment_integer'] = 'true'
investable_flows['capacity'] = 1000.0
investable_flows['is_transport'] = 'true'
# Out:
# C:\Users\urosg\AppData\Local\Temp\ipykernel_25756\1241685987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   investable_flows['investment_integer'] = 'true'

# %%
merged = flow_df.merge(investable_flows[['from_asset', 'to_asset', 'capacity', 'investment_integer', 'is_transport']], on=['from_asset', 'to_asset'], how='left', suffixes=('', '_y'))

merged['investment_integer'] = merged['investment_integer_y']

merged = merged.drop(columns=['investment_integer_y'])

merged['capacity'] = merged['capacity_y']

merged = merged.drop(columns=['capacity_y'])

merged['is_transport'] = merged['is_transport_y']

merged = merged.drop(columns=['is_transport_y'])

merged['investment_integer'] = merged['investment_integer'].fillna('false')

# %%
merged
# Out:
#      capacity      carrier  discount_rate  economic_lifetime  \
# 0         0.0  electricity            0.0                1.0
# 1         0.0  electricity            0.0                1.0
# 2         0.0  electricity            0.0                1.0
# 3         0.0  electricity            0.0                1.0
# 4         0.0  electricity            0.0                1.0
# ..        ...          ...            ...                ...
# 590    1000.0  electricity            0.0                1.0
# 591    1000.0  electricity            0.0                1.0
# 592    1000.0  electricity            0.0                1.0
# 593    1000.0  electricity            0.0                1.0
# 594    1000.0  electricity            0.0                1.0
#
#            from_asset investment_integer  is_transport  technical_lifetime  \
# 0        NL_E_Balance               true         False                 1.0
# 1            NL_E_ENS               true         False                 1.0
# 2     NL_Wind_Onshore               true         False                 1.0
# 3    NL_Wind_Offshore               true         False                 1.0
# 4            NL_Solar               true         False                 1.0
# ..                ...                ...           ...                 ...
# 590      RO_E_Balance              false          True                 1.0
# 591      RO_E_Balance              false          True                 1.0
# 592      CY_E_Balance              false          True                 1.0
# 593   OBZLL_E_Balance              false          True                 1.0
# 594   OBZLL_E_Balance              false          True                 1.0
#
#          to_asset
# 0     NL_E_Demand
# 1     NL_E_Demand
# 2    NL_E_Balance
# 3    NL_E_Balance
# 4    NL_E_Balance
# ..            ...
# 590  BG_E_Balance
# 591  HU_E_Balance
# 592  GR_E_Balance
# 593  NL_E_Balance
# 594  UK_E_Balance
#
# [595 rows x 9 columns]

# %%
merged['is_transport'] = merged['is_transport'].astype(str).str.lower()

# %%
# merged['capacity'] =

# %%
# merged.to_csv('flow-fixed.csv', index=False)
