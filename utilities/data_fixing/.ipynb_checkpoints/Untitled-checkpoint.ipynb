# %%
import pandas as pd

# %%
partition_map = {
    'NL': 1,
    'BE': 2, 'DE': 2, 'UK': 2, 'DK': 2,
    'FR': 3, 'CH': 3, 'AT': 3, 'IE': 3, 'LU': 3, 'CZ': 3, 'PL': 3, 'NO': 3, 'SE': 3,
    'ES': 4, 'IT': 4, 'SI': 4, 'HU': 4, 'SK': 4, 'FI': 4, 'LT': 4,
    'PT': 5, 'HR': 5, 'RO': 5, 'GR': 5, 'LV': 5, 'EE': 5, 'CY': 5, 'MT': 5,
    'BG': 6
}

# %%
df = pd.read_excel('paper_data.xlsx', sheet_name='flow')

# %%
df
# Out:
#           from_asset      to_asset      carrier  is_transport  capacity  \
# 0       NL_E_Balance   BE_E_Demand  electricity          True      1000
# 1       BE_E_Balance   NL_E_Demand  electricity          True      1000
# 2       NL_E_Balance   NL_E_Demand  electricity         False      1000
# 3           NL_E_ENS   NL_E_Demand  electricity         False      1000
# 4    NL_Wind_Onshore  NL_E_Balance  electricity         False      1000
# ..               ...           ...          ...           ...       ...
# 616       CY_Battery      CY_PEMEC  electricity         False      1000
# 617     CY_E_Balance      CY_PEMEC  electricity         False      1000
# 618         CY_PEMEC     CY_H2Tank     hydrogen         False      1000
# 619         CY_PEMFC   CY_E_Demand  electricity         False      1000
# 620        CY_H2Tank      CY_PEMFC     hydrogen         False      1000
#
#      technical_lifetime  economic_lifetime  discount_rate  investment_integer
# 0                    10                  1           0.02               False
# 1                    10                  1           0.02               False
# 2                    10                  1           0.02               False
# 3                    10                  1           0.02               False
# 4                    10                  1           0.02               False
# ..                  ...                ...            ...                 ...
# 616                  10                  1           0.02               False
# 617                  10                  1           0.02               False
# 618                  10                  1           0.02               False
# 619                  10                  1           0.02               False
# 620                  10                  1           0.02               False
#
# [621 rows x 9 columns]

# %%
only_transports_df = df[df['from_asset'].str.contains('E_Balance') & df['to_asset'].str.contains('E_Demand')]

# %%
only_transports_df
# Out:
#        from_asset     to_asset      carrier  is_transport  capacity  \
# 0    NL_E_Balance  BE_E_Demand  electricity          True      1000
# 1    BE_E_Balance  NL_E_Demand  electricity          True      1000
# 2    NL_E_Balance  NL_E_Demand  electricity         False      1000
# 17   BE_E_Balance  BE_E_Demand  electricity         False      1000
# 33   DE_E_Balance  NL_E_Demand  electricity          True      1000
# ..            ...          ...          ...           ...       ...
# 588  HU_E_Balance  RO_E_Demand  electricity          True      1000
# 589  RO_E_Balance  RO_E_Demand  electricity         False      1000
# 608  CY_E_Balance  GR_E_Demand  electricity          True      1000
# 609  GR_E_Balance  CY_E_Demand  electricity          True      1000
# 610  CY_E_Balance  CY_E_Demand  electricity         False      1000
#
#      technical_lifetime  economic_lifetime  discount_rate  investment_integer
# 0                    10                  1           0.02               False
# 1                    10                  1           0.02               False
# 2                    10                  1           0.02               False
# 17                   10                  1           0.02               False
# 33                   10                  1           0.02               False
# ..                  ...                ...            ...                 ...
# 588                  10                  1           0.02               False
# 589                  10                  1           0.02               False
# 608                  10                  1           0.02               False
# 609                  10                  1           0.02               False
# 610                  10                  1           0.02               False
#
# [148 rows x 9 columns]

# %%
new_df = only_transports_df[['from_asset', 'to_asset']]

# %%
europe_graph = {}

for country in partition_map:
#     country = 'PT'
    interested_in = new_df[new_df['from_asset'].str.contains(country) | new_df['to_asset'].str.contains(country)]

    unique_froms = interested_in['from_asset'].unique()
    unique_tos = interested_in['to_asset'].unique()

    uniques = [*unique_froms, *unique_tos]
    uniques_cut = [elem[0:2] for elem in uniques]

    actual_uniques = set(uniques_cut)

    actual_uniques.remove(country)

    europe_graph[country] = actual_uniques
# Out:
# {'NL': 1, 'BE': 2, 'DE': 2, 'UK': 2, 'DK': 2, 'FR': 3, 'CH': 3, 'AT': 3, 'IE': 3, 'LU': 3, 'CZ': 3, 'PL': 3, 'NO': 3, 'SE': 3, 'ES': 4, 'IT': 4, 'SI': 4, 'HU': 4, 'SK': 4, 'FI': 4, 'LT': 4, 'PT': 5, 'HR': 5, 'RO': 5, 'GR': 5, 'LV': 5, 'EE': 5, 'CY': 5, 'MT': 5, 'BG': 6}
# N
# L
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 19
#      15 uniques_cut = [elem[0:2] for elem in uniques]
#      17 actual_uniques = set(uniques_cut)
# ---> 19 actual_uniques.remove(country)
#      21 europe_graph[country] = actual_uniques
#
# KeyError: 'N'
